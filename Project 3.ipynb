# %%
import pandas as pd

# %%
df = pd.read_table('/content/fruit_data_with_colors.txt')
df.head(10)
# Out:
#    fruit_label fruit_name fruit_subtype  mass  width  height  color_score
# 0            1      apple  granny_smith   192    8.4     7.3         0.55
# 1            1      apple  granny_smith   180    8.0     6.8         0.59
# 2            1      apple  granny_smith   176    7.4     7.2         0.60
# 3            2   mandarin      mandarin    86    6.2     4.7         0.80
# 4            2   mandarin      mandarin    84    6.0     4.6         0.79
# 5            2   mandarin      mandarin    80    5.8     4.3         0.77
# 6            2   mandarin      mandarin    80    5.9     4.3         0.81
# 7            2   mandarin      mandarin    76    5.8     4.0         0.81
# 8            1      apple      braeburn   178    7.1     7.8         0.92
# 9            1      apple      braeburn   172    7.4     7.0         0.89

# %%
x = df.iloc[:,3:]
y = df.iloc[:,1]

# %%
from sklearn.model_selection import train_test_split
x_train , x_test , y_train , y_test = train_test_split(x,y,random_state=42)

# %%
# Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(max_depth=2, random_state=0)
clf.fit(x_train,y_train)
# Out:
# RandomForestClassifier(max_depth=2, random_state=0)

# %%
y_pred=clf.predict(x_test)
y_pred
# Out:
# array(['apple', 'mandarin', 'orange', 'orange', 'lemon', 'lemon', 'lemon',
#        'orange', 'lemon', 'apple', 'lemon', 'mandarin', 'orange',
#        'orange', 'apple'], dtype=object)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
accuracy_score(y_pred,y_test)
# Out:
# 0.9333333333333333

# %%
confusion_matrix(y_pred,y_test)
# Out:
# array([[3, 0, 0, 0],
#        [0, 5, 0, 0],
#        [0, 0, 2, 0],
#        [1, 0, 0, 4]])

# %%
print(classification_report(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#        apple       0.75      1.00      0.86         3
#        lemon       1.00      1.00      1.00         5
#     mandarin       1.00      1.00      1.00         2
#       orange       1.00      0.80      0.89         5
#
#     accuracy                           0.93        15
#    macro avg       0.94      0.95      0.94        15
# weighted avg       0.95      0.93      0.93        15

# %%
# Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression(random_state=0)
lr.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# LogisticRegression(random_state=0)

# %%
y_pred = lr.predict(x_test)
y_pred
# Out:
# array(['apple', 'mandarin', 'apple', 'orange', 'orange', 'lemon', 'lemon',
#        'orange', 'lemon', 'apple', 'lemon', 'mandarin', 'orange',
#        'orange', 'orange'], dtype=object)

# %%
accuracy_score(y_pred,y_test)
# Out:
# 0.7333333333333333

# %%
confusion_matrix(y_pred,y_test)
# Out:
# array([[2, 0, 0, 1],
#        [0, 4, 0, 0],
#        [0, 0, 2, 0],
#        [2, 1, 0, 3]])

# %%
print(classification_report(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#        apple       0.50      0.67      0.57         3
#        lemon       0.80      1.00      0.89         4
#     mandarin       1.00      1.00      1.00         2
#       orange       0.75      0.50      0.60         6
#
#     accuracy                           0.73        15
#    macro avg       0.76      0.79      0.77        15
# weighted avg       0.75      0.73      0.72        15

# %%
# Decison classifier

# %%
from sklearn.tree import DecisionTreeClassifier
dc = DecisionTreeClassifier(random_state=0)

# %%
dc.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(random_state=0)

# %%
y_pred = dc.predict(x_test)
y_pred
# Out:
# array(['apple', 'mandarin', 'orange', 'lemon', 'lemon', 'mandarin',
#        'lemon', 'orange', 'lemon', 'apple', 'lemon', 'mandarin', 'orange',
#        'orange', 'apple'], dtype=object)

# %%
accuracy_score(y_pred,y_test)
# Out:
# 0.8666666666666667

# %%
confusion_matrix(y_pred,y_test)
# Out:
# array([[3, 0, 0, 0],
#        [1, 4, 0, 0],
#        [0, 1, 2, 0],
#        [0, 0, 0, 4]])

# %%
print(classification_report(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#        apple       0.75      1.00      0.86         3
#        lemon       0.80      0.80      0.80         5
#     mandarin       1.00      0.67      0.80         3
#       orange       1.00      1.00      1.00         4
#
#     accuracy                           0.87        15
#    macro avg       0.89      0.87      0.86        15
# weighted avg       0.88      0.87      0.86        15

# %%
# Conclusion --> Random Forest Classification is the best ML model for this data with the accuracy = 93.33%
