# %%
import tensorflow as tf
mnist = tf.keras.datasets.fashion_mnist
(training_images, training_labels), (test_images, test_labels) =tf.keras.datasets.fashion_mnist.load_data()
training_images=training_images / 255.0
test_images=test_images / 255.0
import matplotlib.pyplot as plt

# %%
image = training_images[101, :]

plt.imshow(image)
plt.show()

# %%
# !nvidia-smi
# Out:
# Wed Jun 15 11:46:05 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   54C    P0    27W /  70W |   4888MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %%
model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(128, activation=tf.nn.relu),
  tf.keras.layers.Dense(10, activation=tf.nn.softmax)
])

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.fit(training_images, training_labels, epochs=10)

test_loss = model.evaluate(test_images, test_labels)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4943 - accuracy: 0.8258
# Epoch 2/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3733 - accuracy: 0.8637
# Epoch 3/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3363 - accuracy: 0.8779
# Epoch 4/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3140 - accuracy: 0.8850
# Epoch 5/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2964 - accuracy: 0.8909
# Epoch 6/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2804 - accuracy: 0.8961
# Epoch 7/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2679 - accuracy: 0.9003
# Epoch 8/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2572 - accuracy: 0.9043
# Epoch 9/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2475 - accuracy: 0.9080
# Epoch 10/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2393 - accuracy: 0.9100
# 313/313 [==============================] - 1s 2ms/step - loss: 0.3285 - accuracy: 0.8877

# %%
mnist = tf.keras.datasets.fashion_mnist
(training_images, training_labels), (test_images, test_labels) = mnist.load_data()
training_images=training_images.reshape(60000, 28, 28, 1)
training_images=training_images / 255.0
test_images = test_images.reshape(10000, 28, 28, 1)
test_images=test_images/255.0

# %%
model = tf.keras.models.Sequential([
  tf.keras.layers.Conv2D(64, (3,3), activation='relu', input_shape=(28, 28, 1)),
  tf.keras.layers.MaxPooling2D(2, 2),
  tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
  tf.keras.layers.MaxPooling2D(2,2),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dense(10, activation='softmax')
])

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.summary()
model.fit(training_images, training_labels, epochs=5)
test_loss = model.evaluate(test_images, test_labels)
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_9 (Conv2D)           (None, 26, 26, 64)        640
#
#  max_pooling2d_9 (MaxPooling  (None, 13, 13, 64)       0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 11, 11, 64)        36928
#
#  max_pooling2d_10 (MaxPoolin  (None, 5, 5, 64)         0
#  g2D)
#
#  flatten_10 (Flatten)        (None, 1600)              0
#
#  dense_20 (Dense)            (None, 128)               204928
#
#  dense_21 (Dense)            (None, 10)                1290
#
# =================================================================
# Total params: 243,786
# Trainable params: 243,786
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4408 - accuracy: 0.8387
# Epoch 2/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2937 - accuracy: 0.8914
# Epoch 3/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2473 - accuracy: 0.9090
# Epoch 4/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2153 - accuracy: 0.9200
# Epoch 5/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1885 - accuracy: 0.9295
# 313/313 [==============================] - 1s 3ms/step - loss: 0.2584 - accuracy: 0.9079

# %%
print(test_labels[:100])
# Out:
# [9 2 1 1 6 1 4 6 5 7 4 5 7 3 4 1 2 4 8 0 2 5 7 9 1 4 6 0 9 3 8 8 3 3 8 0 7
#  5 7 9 6 1 3 7 6 7 2 1 2 2 4 4 5 8 2 2 8 4 8 0 7 7 8 5 1 1 2 3 9 8 7 0 2 6
#  2 3 1 2 8 4 1 8 5 9 5 0 3 2 0 6 5 3 6 7 1 8 0 1 4 2]

# %%
import matplotlib.pyplot as plt
from tensorflow.keras import models

# %%
mnist = tf.keras.datasets.mnist
(training_images, training_labels), (test_images, test_labels) = mnist.load_data()
training_images=training_images.reshape(60000, 28, 28, 1)
training_images=training_images / 255.0
test_images = test_images.reshape(10000, 28, 28, 1)
test_images=test_images/255.0
model = tf.keras.models.Sequential([
  tf.keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=(28, 28, 1)),
  tf.keras.layers.MaxPooling2D(2, 2),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dense(10, activation='softmax')
])

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.fit(training_images, training_labels, epochs=10)
test_loss, test_acc = model.evaluate(test_images, test_labels)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1498 - accuracy: 0.9556
# Epoch 2/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0513 - accuracy: 0.9845
# Epoch 3/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0322 - accuracy: 0.9897
# Epoch 4/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0220 - accuracy: 0.9928
# Epoch 5/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0144 - accuracy: 0.9954
# Epoch 6/10
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0101 - accuracy: 0.9962
# Epoch 7/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0078 - accuracy: 0.9972
# Epoch 8/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0058 - accuracy: 0.9981
# Epoch 9/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0057 - accuracy: 0.9982
# Epoch 10/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0042 - accuracy: 0.9987
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0529 - accuracy: 0.9877

# %%
print(test_acc)
# Out:
# 0.9876999855041504

# %%
import numpy as np
image_pred=model.predict(test_images)
image_pred=np.argmax(image_pred,axis=1)
image_pred
# Out:
# array([7, 2, 1, ..., 4, 5, 6])

# %%
test_labels
# Out:
# array([7, 2, 1, ..., 4, 5, 6], dtype=uint8)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(image_pred,test_labels)
# Out:
# 0.9877
